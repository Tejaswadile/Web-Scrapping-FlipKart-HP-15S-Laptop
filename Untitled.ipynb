# %%
import pandas as pd

# %%
pd.read_csv("HP flipcart product scrapping")
# Out:
#                      Name  Stars  \
# 0         Vaibhav Bharati      4
# 1           MD MATHIN ALI      5
# 2       Sayani  Banerjee       5
# 3          Satyajit Swain      3
# 4  Vijay Singh  Shekhawat      3
# 5            Anoop Mathew      5
# 6            Vivek Raturi      3
# 7        Anand Amirtharaj      4
# 8       Flipkart Customer      4
# 9         Shivani  Pankaj      4
#
#                                              Reviews           Comments
# 0  Read carefully.. My Experience was complicated...          Very Good
# 1  #Price up to markIts wonderful product for tho...           Terrific
# 2  Nice laptop and Ryzen 3 is a good processor fo...  Worth every penny
# 3  This laptop needs to be upgraded to at least 8...               Fair
# 4  HP Product is Good/Ok, but personally i will p...               Fair
# 5  Awesome and nice for students and all. The fav...          Just wow!
# 6  Do not expect much :1)Very slow takes a lot of...               Good
# ...
